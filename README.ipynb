# %% [markdown]
# <a href="https://colab.research.google.com/github/RuW251/final_proj/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
# The repository is a project of using the The dataset "Used Cars Dataset" (https://www.kaggle.com/austinreese/craigslist-carstrucks-data) to predict a linear relationship between "odometer of vehicles", "verhicle drive types(front-wheel drive etc)", "vehicle types(SUV etc)", "paint color of vehicles" and the price of the used cars in United States.
#
# The notebook "car_price_predict.ipynb" provides all the codes, plots, comments, and summary of the data science process of discovering the relationship between the listed price and our predictors. The video in this repository walks you through the notebook by providing detailed explanation of author's ideas.
#
# The Dataset containing collections of used vehicles for sale on Craigslist. The dataset includes every used vehicle entry within the United States on Craigslist and is updated every few months. The dataset I am using is last updated in January 2020. The dataset is about 1.42 GB.

# %% [markdown]
# ## Some Statistics and plots from the notebook

# %% [markdown]
# Here are 3 plots from the notebook to give you an idea of how I work with the dataset

# %% [markdown]
# Here is a glance at the data

# %% [markdown]
# ![summary.PNG](data:image/png;base64,...)

# %% [markdown]
# A plot of number of listed cars for each year from the dataset

# %% [markdown]
# ![num_listed_car.PNG](data:image/png;base64,...)

# %% [markdown]
# Car type and their corresponding price distribution.

# %% [markdown]
# ![type.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Data Collection Process

# %% [markdown]
# The notebook I implemented is a kaggle notebook and the dataset is already available on kaggle. I simple set the file path and directly read the csv files from kaggle into my kaggle notebook.
